# %%
import numpy as np

# %% [markdown]
# #### Data generation

# %%
def generate_data(row, col):
    std_marks = np.random.randint(0, 101, size=(row, col)).reshape(row, col)
    return std_marks

# %% [markdown]
# #### Analysis

# %%
def avg_marks_per_std(arr):
    return

def avg_marks_per_subj(arr):
    return

def grading_sys(arr):
    return

def topper_std(arr):
    return

def weakest_std(arr):
    return

def best_subj(arr):
    return

def toughest_subj(arr):
    return

# %% [markdown]
# #### Reporting

# %% [markdown]
# #### Visualization

# %% [markdown]
# #### Execution pipeline
